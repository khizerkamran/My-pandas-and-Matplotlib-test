# %% [markdown]
# # Task 1

# %%
#1.series is a column and a dataframe is a multi-dimensional table
#2.series has 1 portion where the dataset is but dataframe can contain many portions other than 1
import pandas as pd
data={
'Coutry': ['Itly','Spain','Greece','France','Portugal'],
'Popu':[61,46,11,65,10],
'Percent':[0.83,0.63,0.15,0.88,0.14]   
}
createDataFrame= pd.DataFrame(data, index=['IT' , 'ES' ,'GR' ,'FR','PO'])
createDataFrame
# Out:
#       Coutry  Popu  Percent
# IT      Itly    61     0.83
# ES     Spain    46     0.63
# GR    Greece    11     0.15
# FR    France    65     0.88
# PO  Portugal    10     0.14

# %% [markdown]
# # Task 2

# %%
dataset=pd.read_csv("C:/python profestinal/test 4 pandas and matplotlib/Dataset 1.csv")
dataset
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub-Saharan Africa                 Angola        Household
# 7                  Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %%
summary= len(dataset.index)-dataset.count()
summary
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        2
# Unit Price        2
# Unit Cost         1
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
xyz=dataset.fillna(0)
xyz
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub-Saharan Africa                 Angola        Household
# 7                  Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          29 non-null     object
#  1   Country         29 non-null     object
#  2   Item Type       29 non-null     object
#  3   Sales Channel   29 non-null     object
#  4   Order Priority  29 non-null     object
#  5   Order Date      29 non-null     object
#  6   Order ID        29 non-null     int64
#  7   Ship Date       29 non-null     object
#  8   Units Sold      27 non-null     float64
#  9   Unit Price      27 non-null     float64
#  10  Unit Cost       28 non-null     float64
#  11  Total Revenue   29 non-null     float64
#  12  Total Cost      29 non-null     float64
#  13  Total Profit    29 non-null     float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 3.3+ KB

# %%
dataset.loc[5:20]
# Out:
#                                Region                Country      Item Type  \
# 5               Australia and Oceania        Solomon Islands      Baby Food
# 6                  Sub-Saharan Africa                 Angola      Household
# 7                  Sub-Saharan Africa           Burkina Faso     Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo  Personal Care
# 9                  Sub-Saharan Africa                Senegal         Cereal
# 10                               Asia             Kyrgyzstan     Vegetables
# 11                 Sub-Saharan Africa             Cape Verde        Clothes
# 12                               Asia             Bangladesh        Clothes
# 13  Central America and the Caribbean               Honduras      Household
# 14                               Asia               Mongolia  Personal Care
# 15                             Europe               Bulgaria        Clothes
# ...

# %% [markdown]
# # Task 3

# %%
dataset=pd.read_csv("C:/python profestinal/test 4 pandas and matplotlib/Dataset 2.csv")
dataset
# Out:
#           Date  Battery Voltage AVG  Temperature AVG  Relative Humidity AVG  \
# 0   12/31/2015            13.845000        19.062917              21.870833
# 1   12/30/2015            13.822917        14.631208              18.493833
# 2   12/29/2015            13.834583         6.614292              34.072917
# 3   12/28/2015            13.710417         8.687042              70.557917
# 4   12/27/2015            13.362500        14.140417              95.754167
# 5   12/26/2015            13.531667        17.512917              47.574583
# 6   12/25/2015            13.837083         3.215042              33.722500
# 7   12/24/2015            13.681667         2.815375              76.065833
# 8   12/23/2015            13.371667         2.005458              90.891667
# 9   12/22/2015            13.681250         4.028125              91.316667
# 10  12/21/2015            13.252500         8.244375              93.583333
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset.plot.bar(y=['Temperature AVG','Relative Humidity AVG','Wind Speed Daily AVG','Solare Radiation AVG'], x='Battery Voltage AVG',

subplots=True, layout=(2,2))
# Out:
# c:\users\fazz communication\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'Temperature AVG'}, xlabel='Battery Voltage AVG'>,
#         <AxesSubplot:title={'center':'Relative Humidity AVG'}, xlabel='Battery Voltage AVG'>],
#        [<AxesSubplot:title={'center':'Wind Speed Daily AVG'}, xlabel='Battery Voltage AVG'>,
#         <AxesSubplot:title={'center':'Solare Radiation AVG'}, xlabel='Battery Voltage AVG'>]],
#       dtype=object)

# %%
y=[2,4,1,5,6,2]
x=[1,2,3,4,5,6]
plt.title('Some Cool Custumization!')
plt.ylabel('y-axis')
plt.xlabel('x-axis')

plt.plot(y, x,color='green',marker='o',markerfacecolor='blue',linestyle='--')

# %%
z=pd.read_csv("Dataset 2.csv",index_col=0).head(3)
z
# Out:
#             Battery Voltage AVG  Temperature AVG  Relative Humidity AVG  \
# Date
# 12/31/2015            13.845000        19.062917              21.870833
# 12/30/2015            13.822917        14.631208              18.493833
# 12/29/2015            13.834583         6.614292              34.072917
#
#             Wind Speed Daily AVG  Wind Direction AVG  Solare Radiation AVG
# Date
# 12/31/2015             21.977792           62.325833             84.915292
# 12/30/2015              3.540542          121.505417             86.192833
# 12/29/2015              0.000000          130.291667             85.100917

# %%
z.plot.pie(subplots=True)
# Out:
# c:\users\fazz communication\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([<AxesSubplot:ylabel='Battery Voltage AVG'>,
#        <AxesSubplot:ylabel='Temperature AVG'>,
#        <AxesSubplot:ylabel='Relative Humidity AVG'>,
#        <AxesSubplot:ylabel='Wind Speed Daily AVG'>,
#        <AxesSubplot:ylabel='Wind Direction AVG'>,
#        <AxesSubplot:ylabel='Solare Radiation AVG'>], dtype=object)
